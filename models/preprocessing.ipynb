# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\xhu70\Projects\twel_data_collection\data\sensor_data.csv")

# %%
df.head()
# Out:
#              timestamp  temperature_c  humidity_pct  pressure_hpa
# 0  2026-03-07T18:12:00          27.17         27.88       1012.39
# 1  2026-03-07T18:12:10          27.16         27.64       1012.42
# 2  2026-03-07T18:12:20          27.16         27.53       1012.41
# 3  2026-03-07T18:12:30          27.15         27.39       1012.39
# 4  2026-03-07T18:12:40          27.15         27.76       1012.44

# %%
df.shape
# Out:
# (10279, 4)

# %%
df.dtypes
# Out:
# timestamp            str
# temperature_c    float64
# humidity_pct     float64
# pressure_hpa     float64
# dtype: object

# %%
df['timestamp']=pd.to_datetime(df['timestamp'])

# %%
df.head()
# Out:
#             timestamp  temperature_c  humidity_pct  pressure_hpa
# 0 2026-03-07 18:12:00          27.17         27.88       1012.39
# 1 2026-03-07 18:12:10          27.16         27.64       1012.42
# 2 2026-03-07 18:12:20          27.16         27.53       1012.41
# 3 2026-03-07 18:12:30          27.15         27.39       1012.39
# 4 2026-03-07 18:12:40          27.15         27.76       1012.44

# %%
df=df.set_index('timestamp')

# %%
df.head()
# Out:
#                      temperature_c  humidity_pct  pressure_hpa
# timestamp
# 2026-03-07 18:12:00          27.17         27.88       1012.39
# 2026-03-07 18:12:10          27.16         27.64       1012.42
# 2026-03-07 18:12:20          27.16         27.53       1012.41
# 2026-03-07 18:12:30          27.15         27.39       1012.39
# 2026-03-07 18:12:40          27.15         27.76       1012.44

# %%
df.isnull().sum
# Out:
# <bound method DataFrame.sum of                      temperature_c  humidity_pct  pressure_hpa
# timestamp
# 2026-03-07 18:12:00          False         False         False
# 2026-03-07 18:12:10          False         False         False
# 2026-03-07 18:12:20          False         False         False
# 2026-03-07 18:12:30          False         False         False
# 2026-03-07 18:12:40          False         False         False
# ...                            ...           ...           ...
# 2026-03-08 23:47:14          False         False         False
# 2026-03-08 23:47:24          False         False         False
# 2026-03-08 23:47:34          False         False         False
# 2026-03-08 23:47:44          False         False         False
# 2026-03-08 23:47:54          False         False         False
#
# [10279 rows x 3 columns]>

# %%
df.describe()
# Out:
#        temperature_c  humidity_pct  pressure_hpa
# count   10279.000000  10279.000000  10279.000000
# mean       26.803076     21.060424   1010.224438
# std         4.944224      3.694204      2.420791
# min        21.010000     14.270000   1005.560000
# 25%        23.020000     18.950000   1007.980000
# 50%        24.870000     20.900000   1010.910000
# 75%        30.485000     22.870000   1012.220000
# max        39.440000     36.870000   1013.550000

# %%
df["temperature_c"].plot()
# Out:
# <Axes: xlabel='timestamp'>

# %%
df["humidity_pct"].plot()
# Out:
# <Axes: xlabel='timestamp'>

# %%
df["pressure_hpa"].plot()
# Out:
# <Axes: xlabel='timestamp'>

# %%
plt.figure()
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df["temperature_c"].plot()
df["temperature_c"].rolling(window=360).mean().plot()
# Out:
# <Axes: xlabel='timestamp'>
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
